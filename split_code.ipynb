# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

train_csv = pd.read_csv("/content/drive/MyDrive/FracAtlas/FracAtlas/Utilities/Fracture Split/train.csv")
test_csv = pd.read_csv("/content/drive/MyDrive/FracAtlas/FracAtlas/Utilities/Fracture Split/test.csv")
valid_csv = pd.read_csv("/content/drive/MyDrive/FracAtlas/FracAtlas/Utilities/Fracture Split/valid.csv")

# %%
train_csv
# Out:
#            image_id
# 0    IMG0000019.jpg
# 1    IMG0000025.jpg
# 2    IMG0000044.jpg
# 3    IMG0000057.jpg
# 4    IMG0000058.jpg
# ..              ...
# 569  IMG0003267.jpg
# 570  IMG0003279.jpg
# 571  IMG0003280.jpg
# 572  IMG0003293.jpg
# 573  IMG0003294.jpg
#
# [574 rows x 1 columns]

# %%
test_csv
# Out:
#           image_id
# 0   IMG0003297.jpg
# 1   IMG0003298.jpg
# 2   IMG0003301.jpg
# 3   IMG0003308.jpg
# 4   IMG0003309.jpg
# ..             ...
# 56  IMG0003686.jpg
# 57  IMG0003703.jpg
# 58  IMG0003704.jpg
# 59  IMG0003712.jpg
# 60  IMG0003713.jpg
#
# [61 rows x 1 columns]

# %%
valid_csv
# Out:
#           image_id
# 0   IMG0003733.jpg
# 1   IMG0003734.jpg
# 2   IMG0003766.jpg
# 3   IMG0003767.jpg
# 4   IMG0003770.jpg
# ..             ...
# 77  IMG0004369.jpg
# 78  IMG0004370.jpg
# 79  IMG0004374.jpg
# 80  IMG0004375.jpg
# 81  IMG0004376.jpg
#
# [82 rows x 1 columns]

# %%
'''#creating fractured folder in these paths
# !mkdir "/content/drive/MyDrive/FracAtlas/test/Fractured"
# !mkdir "/content/drive/MyDrive/FracAtlas/train/Fractured"
# !mkdir "/content/drive/MyDrive/FracAtlas/valid/Fractured"'''

# %% [markdown]
# training dataset creation

# %%
'''#copying images from fractured file into train file as per train.csv file's image id
import cv2

for image_id in train_csv["image_id"]:#range is image_id of train_csv
  image_input_path = "/content/drive/MyDrive/FracAtlas/FracAtlas/images/Fractured/"+str(image_id)#getting images as per image_id
  image_output_path = "/content/drive/MyDrive/FracAtlas/train/Fractured/"

  image = cv2.imread(image_input_path)#taking images as input
  cv2.imwrite(image_output_path + str(image_id), image)#copying files in train folder that takes input before'''

print("Train files copied")
# Out:
# Train files copied

# %%
'''import os
import cv2
import random


dirs = []
for i in os.listdir("/content/drive/MyDrive/FracAtlas/FracAtlas/images/Non_fractured/"):
    if i.endswith(".jpg"):
        dirs.append(os.path.join("/content/drive/MyDrive/FracAtlas/FracAtlas/images/Non_fractured/", i))


image_paths = random.sample(dirs, 2693) #80% of non-fractured images


for image_path in image_paths:
  image_output_path = "/content/drive/MyDrive/FracAtlas/train/Non_fractured/"
  image_name = image_path.split("/")[-1]
  # print(image_name)
  image = cv2.imread(image_path)
  cv2.imwrite(image_output_path + str(image_name), image)
# pic = cv2.imread(pic)'''
print("Nonfractured Train Images Copied")
# Out:
# Nonfractured Train Images Copied

# %%
'''#copying annotations for fracture from segmentation folder to train set
import os
import shutil #shutil stands for shell utility and it inlcudes operations link copying, deleting and moving

dirs1=[]
count1=0
for i in os.listdir("/content/drive/MyDrive/FracAtlas/train/Fractured/"):
    if i.endswith(".jpg"):
        image_id = i.split("/")[-1]
        dirs1.append(image_id)
        count1=count1+1
        #print(image_id)
#print(dirs1)
print("total items in jpg format: ",count1)

dirs2=[]
count2=0
for j in os.listdir("/content/drive/MyDrive/FracAtlas/Segmentation/"):
    if j.endswith(".txt"):
        image_name = j.split("/")[-1]
        dirs2.append(image_name)
        count2=count2+1
        #print(image_name)
#print(dirs2)
print("total items in txt format: ",count2)

source_dir = "/content/drive/MyDrive/FracAtlas/Segmentation/"
destination_dir = "/content/drive/MyDrive/FracAtlas/train/Fractured/"

count3=0
for i in dirs1:
    if i.endswith(".jpg"):
        image_id = i.split(".")[0]
        #print(image_id)
        for j in dirs2:
            if j.endswith(".txt"):
                image_name = j.split(".")[0]
                #print(image_name)
                if image_id==image_name:
                    source_file = os.path.join(source_dir, j)
                    destination_file = os.path.join(destination_dir, j)
                    shutil.copy(source_file, destination_file)
                    count3=count3+1
print(count3)'''

print("annotation files for train fracture dataset copied")
# Out:
# total items in jpg format:  574
# total items in txt format:  4084
# 574
# annotation files for train fracture dataset copied

# %%
'''#copying annotations for non fracture from segmentation folder to train set
import os
import shutil

dirs1=[]
count1=0
for i in os.listdir("/content/drive/MyDrive/FracAtlas/train/Non_fractured/"):
    if i.endswith(".jpg"):
        image_id = i.split("/")[-1]
        dirs1.append(image_id)
        count1=count1+1
        #print(image_id)
#print(dirs1)
print("total items in jpg format: ",count1)

dirs2=[]
count2=0
for j in os.listdir("/content/drive/MyDrive/FracAtlas/Segmentation/"):
    if j.endswith(".txt"):
        image_name = j.split("/")[-1]
        dirs2.append(image_name)
        count2=count2+1
        #print(image_name)
#print(dirs2)
print("total items in txt format: ",count2)

source_dir = "/content/drive/MyDrive/FracAtlas/Segmentation/"
destination_dir = "/content/drive/MyDrive/FracAtlas/train/Non_fractured/"

count3=0
for i in dirs1:
    if i.endswith(".jpg"):
        image_id = i.split(".")[0]
        #print(image_id)
        for j in dirs2:
            if j.endswith(".txt"):
                image_name = j.split(".")[0]
                #print(image_name)
                if image_id==image_name:
                    source_file = os.path.join(source_dir, j)
                    destination_file = os.path.join(destination_dir, j)
                    shutil.copy(source_file, destination_file)
                    count3=count3+1
print(count3)'''

print("annotation files for train non fracture dataset copied")
# Out:
# total items in jpg format:  2693
# total items in txt format:  4084
# 2693
# annotation files for train non fracture dataset copied

# %% [markdown]
# testing dataset creation

# %%
'''#copying images from fractured file into test file as per test.csv file's image id
import cv2

for image_id in test_csv["image_id"]: #range is image_id of test_csv
  image_input_path = "/content/drive/MyDrive/FracAtlas/FracAtlas/images/Fractured/"+str(image_id)#getting images as per image_id
  image_output_path = "/content/drive/MyDrive/FracAtlas/test/Fractured/"

  image = cv2.imread(image_input_path)#taking images as input
  cv2.imwrite(image_output_path + str(image_id), image)#copying files in test folder that takes input before'''

print("Test files copied")
# Out:
# Test files copied

# %%
'''import os
import cv2
import random


dirs = []
for i in os.listdir("/content/drive/MyDrive/FracAtlas/FracAtlas/images/Non_fractured/"):
    if i.endswith(".jpg"):
        dirs.append(os.path.join("/content/drive/MyDrive/FracAtlas/FracAtlas/images/Non_fractured/", i))


image_paths = random.sample(dirs, 286) #8.5% of non-fractured images


for image_path in image_paths:
  image_output_path = "/content/drive/MyDrive/FracAtlas/test/Non_fractured/"
  image_name = image_path.split("/")[-1]
  # print(image_name)
  image = cv2.imread(image_path)
  cv2.imwrite(image_output_path + str(image_name), image)
# pic = cv2.imread(pic)'''
print("Nonfractured Test Images Copied")
# Out:
# Nonfractured Test Images Copied

# %%
'''#copying annotations for fracture from segmentation folder to test set
import os
import shutil

dirs1=[]
count1=0
for i in os.listdir("/content/drive/MyDrive/FracAtlas/test/Fractured/"):
    if i.endswith(".jpg"):
        image_id = i.split("/")[-1]
        dirs1.append(image_id)
        count1=count1+1
        #print(image_id)
#print(dirs1)
print("total items in jpg format: ",count1)

dirs2=[]
count2=0
for j in os.listdir("/content/drive/MyDrive/FracAtlas/Segmentation/"):
    if j.endswith(".txt"):
        image_name = j.split("/")[-1]
        dirs2.append(image_name)
        count2=count2+1
        #print(image_name)
#print(dirs2)
print("total items in txt format: ",count2)

source_dir = "/content/drive/MyDrive/FracAtlas/Segmentation/"
destination_dir = "/content/drive/MyDrive/FracAtlas/test/Fractured/"

count3=0
for i in dirs1:
    if i.endswith(".jpg"):
        image_id = i.split(".")[0]
        #print(image_id)
        for j in dirs2:
            if j.endswith(".txt"):
                image_name = j.split(".")[0]
                #print(image_name)
                if image_id==image_name:
                    source_file = os.path.join(source_dir, j)
                    destination_file = os.path.join(destination_dir, j)
                    shutil.copy(source_file, destination_file)
                    count3=count3+1'''

print("annotation files for test fracture dataset copied")
# Out:
# total items in jpg format:  61
# total items in txt format:  4084
# annotation files for test fracture dataset copied

# %%
'''#copying annotations for non fracture from segmentation folder to test set
import os
import shutil

dirs1=[]
count1=0
for i in os.listdir("/content/drive/MyDrive/FracAtlas/test/Non_fractured/"):
    if i.endswith(".jpg"):
        image_id = i.split("/")[-1]
        dirs1.append(image_id)
        count1=count1+1
        #print(image_id)
#print(dirs1)
print("total items in jpg format: ",count1)

dirs2=[]
count2=0
for j in os.listdir("/content/drive/MyDrive/FracAtlas/Segmentation/"):
    if j.endswith(".txt"):
        image_name = j.split("/")[-1]
        dirs2.append(image_name)
        count2=count2+1
        #print(image_name)
#print(dirs2)
print("total items in txt format: ",count2)

source_dir = "/content/drive/MyDrive/FracAtlas/Segmentation/"
destination_dir = "/content/drive/MyDrive/FracAtlas/test/Non_fractured/"

count3=0
for i in dirs1:
    if i.endswith(".jpg"):
        image_id = i.split(".")[0]
        #print(image_id)
        for j in dirs2:
            if j.endswith(".txt"):
                image_name = j.split(".")[0]
                #print(image_name)
                if image_id==image_name:
                    source_file = os.path.join(source_dir, j)
                    destination_file = os.path.join(destination_dir, j)
                    shutil.copy(source_file, destination_file)
                    count3=count3+1
print(count3)'''

print("annotation files for test non fracture dataset copied")
# Out:
# total items in jpg format:  286
# total items in txt format:  4084
# 286
# annotation files for test fracture dataset copied

# %% [markdown]
# valid dataset creation

# %%
'''#copying images from fractured file into valid file as per valid.csv file's image id
import cv2

for image_id in valid_csv["image_id"]: #range is image_id of valid_csv
  image_input_path = "/content/drive/MyDrive/FracAtlas/FracAtlas/images/Fractured/"+str(image_id)#getting images as per image_id
  image_output_path = "/content/drive/MyDrive/FracAtlas/valid/Fractured/"

  image = cv2.imread(image_input_path)#taking images as input
  cv2.imwrite(image_output_path + str(image_id), image)#copying files in valid folder that takes input before'''

print("Valid image files copied")
# Out:
# Valid image files copied

# %%
'''import os
import cv2
import random


dirs = []
for i in os.listdir("/content/drive/MyDrive/FracAtlas/FracAtlas/images/Non_fractured/"):
    if i.endswith(".jpg"):
        dirs.append(os.path.join("/content/drive/MyDrive/FracAtlas/FracAtlas/images/Non_fractured/", i))


image_paths = random.sample(dirs, 387) #11.5% of non-fractured images


for image_path in image_paths:
  image_output_path = "/content/drive/MyDrive/FracAtlas/valid/Non_fractured/"
  image_name = image_path.split("/")[-1]
  # print(image_name)
  image = cv2.imread(image_path)
  cv2.imwrite(image_output_path + str(image_name), image)
# pic = cv2.imread(pic)'''
print("Non-fractured valid Images Copied")
# Out:
# Non-fractured valid Images Copied

# %%
'''#copying annotations for fracture from segmentation folder to valid set
import os
import shutil

dirs1=[]
count1=0
for i in os.listdir("/content/drive/MyDrive/FracAtlas/valid/Fractured/"):
    if i.endswith(".jpg"):
        image_id = i.split("/")[-1]
        dirs1.append(image_id)
        count1=count1+1
        #print(image_id)
#print(dirs1)
print("total items in jpg format: ",count1)

dirs2=[]
count2=0
for j in os.listdir("/content/drive/MyDrive/FracAtlas/Segmentation/"):
    if j.endswith(".txt"):
        image_name = j.split("/")[-1]
        dirs2.append(image_name)
        count2=count2+1
        #print(image_name)
#print(dirs2)
print("total items in txt format: ",count2)

source_dir = "/content/drive/MyDrive/FracAtlas/Segmentation/"
destination_dir = "/content/drive/MyDrive/FracAtlas/valid/Fractured/"

count3=0
for i in dirs1:
    if i.endswith(".jpg"):
        image_id = i.split(".")[0]
        #print(image_id)
        for j in dirs2:
            if j.endswith(".txt"):
                image_name = j.split(".")[0]
                #print(image_name)
                if image_id==image_name:
                    source_file = os.path.join(source_dir, j)
                    destination_file = os.path.join(destination_dir, j)
                    shutil.copy(source_file, destination_file)
                    count3=count3+1
print(count3)'''

print("annotation files for valid fracture dataset copied")
# Out:
# total items in jpg format:  82
# total items in txt format:  4084
# 82
# annotation files for valid fracture dataset copied

# %%
'''#copying annotations for non fracture from segmentation folder to valid set
import os
import shutil

dirs1=[]
count1=0
for i in os.listdir("/content/drive/MyDrive/FracAtlas/valid/Non_fractured/"):
    if i.endswith(".jpg"):
        image_id = i.split("/")[-1]
        dirs1.append(image_id)
        count1=count1+1
        #print(image_id)
#print(dirs1)
print("total items in jpg format: ",count1)

dirs2=[]
count2=0
for j in os.listdir("/content/drive/MyDrive/FracAtlas/Segmentation/"):
    if j.endswith(".txt"):
        image_name = j.split("/")[-1]
        dirs2.append(image_name)
        count2=count2+1
        #print(image_name)
#print(dirs2)
print("total items in txt format: ",count2)

source_dir = "/content/drive/MyDrive/FracAtlas/Segmentation/"
destination_dir = "/content/drive/MyDrive/FracAtlas/valid/Non_fractured/"

count3=0
for i in dirs1:
    if i.endswith(".jpg"):
        image_id = i.split(".")[0]
        #print(image_id)
        for j in dirs2:
            if j.endswith(".txt"):
                image_name = j.split(".")[0]
                #print(image_name)
                if image_id==image_name:
                    source_file = os.path.join(source_dir, j)
                    destination_file = os.path.join(destination_dir, j)
                    shutil.copy(source_file, destination_file)
                    count3=count3+1
print(count3)'''

print("annotation files for valid non fracture dataset copied")
# Out:
# total items in jpg format:  387
# total items in txt format:  4084
# 387
# annotation files for valid non fracture dataset copied

# %% [markdown]
# Training YOLO-8s on the FracAtlas Dataset

# %%
#system setup
#System Information
# !nvidia-smi
# !python --version
# Out:
# Mon Nov 27 20:30:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#Run If you don't have ultralytics installed
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.9/645.9 kB 9.3 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# Training of YOLO8s-seg model for segmentation tasks

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=/content/drive/MyDrive/FracAtlas/FracAtlas/data.yaml epochs=30 imgsz=600
# Out:
# ...
# 100% 22.8M/22.8M [00:00<00:00, 383MB/s]
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Training results for the segmentation model

# %%
Image(filename="runs/segment/train/results.png", width=600)

# %%
Image(filename="runs/segment/train/confusion_matrix.png", width=600)

# %% [markdown]
# ## Training of YOLO8s model for localization tasks

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/FracAtlas/FracAtlas/data.yaml epochs=30 imgsz=600
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 151MB/s]
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename="runs/detect/train/results.png", width=600)

# %%
Image(filename="runs/detect/train/confusion_matrix.png", width=600)

# %% [markdown]
# Training for YOLO5 Model for Classification task

# %%
# !yolo task=detect mode=train model=yolov5s.pt data=/content/drive/MyDrive/FracAtlas/FracAtlas/data.yaml epochs=30 imgsz=600
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 17.7M/17.7M [00:00<00:00, 136MB/s]
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
